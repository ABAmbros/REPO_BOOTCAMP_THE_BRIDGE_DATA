# %% [markdown]
# https://towardsdatascience.com/random-forest-in-python-24d0893d51c0
#
# # Ejercicio Regression Tree
# Son datos de temperaturas tomados de la ciudad de Seattle. El objetivo es intentar predecir lo mejor posible la máxima temperatura (columna `actual`) que alcanzaremos al día siguiente. Para ello contaremos con temperaturas de los dos días anteriores, históricos de máximas temperaturas y un amigo bastante chapas que te da su predicción del tiempo cada día.
#
# **Resumen de datos**:
# * year: 2016 for all data points
# * month: number for month of the year
# * day: number for day of the year
# * week: day of the week as a character string
# * temp_2: max temperature 2 days prior
# * temp_1: max temperature 1 day prior
# * average: historical average max temperature
# * actual: max temperature measurement
# * friend: your friend’s prediction, a random number between 20 below the average and 20 above the average
#
#
# ### 1. Importa el csv "temps.csv"

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_temp = pd.read_csv('data/temps.csv', sep=',')

# %%
# Use datetime para tratar con fechas
import datetime

# Use datetime para tratar con fechas
years = data_temp['year']
months = data_temp['month']
days = data_temp['day']

# Listar y luego convertir a objeto de fecha y hora
dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]

# %%
# Para saber los estilos disponibles que tengo para el gráfico
plt.style.available

# %%
# Estilo de las gráficas
plt.style.use('seaborn-paper')

# Configurar el diseño de trazado
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize = (10,10))
fig.autofmt_xdate(rotation = 45)

# Medición de temperatura máxima real
ax1.plot(dates, data_temp['actual'])
ax1.set_xlabel(''); ax1.set_ylabel('Temperature'); ax1.set_title('Temperatura máxima')

# Temperatura de hace 1 día
ax2.plot(dates, data_temp['temp_1'])
ax2.set_xlabel(''); ax2.set_ylabel('Temperature'); ax2.set_title('Temperatura máxima ayer')

# Temperatura de hace 2 días
ax3.plot(dates, data_temp['temp_2'])
ax3.set_xlabel('Date'); ax3.set_ylabel('Temperature'); ax3.set_title('Temperatura máxima hace dos días')

# Estimación de un amigo
ax4.plot(dates, data_temp['friend'])
ax4.set_xlabel('Date'); ax4.set_ylabel('Temperature'); ax4.set_title('Predicción de mi cuñado')

plt.tight_layout(pad=2)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### 2. Lidia con las variables categóricas del dataset

# %%
data_temp = pd.get_dummies(data_temp)

# %% [markdown]
# ### 3. Divide en train y test

# %% [markdown]
# ### 4. Entrena el modelo
# Utiliza un DecisionTreeRegressor

# %% [markdown]
# ### 5. Calcula su MAE
# Sin usar sklearn

# %% [markdown]
# ### 6. Calcula su MAPE
# Sin usar sklearn

# %% [markdown]
# ### 7. Representa el árbol de decision

# %% [markdown]
# ### 8. Modifica el max_depth a 3 y vuelve a entrenarlo

# %% [markdown]
# ### 9. Vuelve a calcular si MAE

# %% [markdown]
# ### 10. Vuelve a representar su árbol

# %% [markdown]
# ### 10. Obten el `feature_importances` de cada variable en el último modelo
