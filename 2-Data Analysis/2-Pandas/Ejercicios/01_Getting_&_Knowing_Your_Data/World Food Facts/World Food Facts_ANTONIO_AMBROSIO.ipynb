# %% [markdown]
# # Ex1 - Getting and knowing your Data

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ###  Step 2. Download the dataset to your computer and unzip it.

# %%
import numpy as np
import pandas as pd

pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
food = pd.read_csv('/Users/antoineambros/Documents/Github/TheBridge/Personal/REPOABAmbros/2-Data Analysis/2-Pandas/Ejercicios/01_Getting_&_Knowing_Your_Data/World Food Facts/food_100.csv')
food.head(10)
# Out:
#    Unnamed: 0   code                                                url  \
# 0           0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1           1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2           2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3           3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4           4  16094  http://world-en.openfoodfacts.org/product/0000...
# 5           5  16100  http://world-en.openfoodfacts.org/product/0000...
# 6           6  16117  http://world-en.openfoodfacts.org/product/0000...
# 7           7  16124  http://world-en.openfoodfacts.org/product/0000...
# 8           8  16193  http://world-en.openfoodfacts.org/product/0000...
# 9           9  16513  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# ...

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.iloc[:5]
# Out:
#    Unnamed: 0   code                                                url  \
# 0           0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1           1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2           2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3           3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4           4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#    last_modified_t last_modified_datetime                    product_name  \
# ...

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.shape
# Out:
# (100, 164)

# %%
len(food)
# Out:
# 100

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
food.columns
# Out:
# Index(['Unnamed: 0', 'code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=164)

# %%
len(food.columns)
# Out:
# 164

# %%
food.shape
# Out:
# (100, 164)

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(food.columns)
# Out:
# Index(['Unnamed: 0', 'code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=164)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-sucrose_100g'

# %%
food.iloc[:, [104]].dtypes
# Out:
# -sucrose_100g    float64
# dtype: object

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food.dtypes['-sucrose_100g']
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
print(food.index)
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food.iloc[:, [19]]
# Out:
#     origins_tags
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# 30           NaN
# 31           NaN
# 32           NaN
# 33           NaN
# 34           NaN
# 35           NaN
# 36           NaN
# 37           NaN
# 38           NaN
# 39           NaN
# 40           NaN
# 41           NaN
# 42           NaN
# 43           NaN
# 44           NaN
# 45           NaN
# 46           NaN
# 47           NaN
# 48           NaN
# 49           NaN
# 50           NaN
# ...
