# %% [markdown]
# # Ejercicio de repaso: BBDD Relacionales

# %% [markdown]
# Ejercicio sacado directamente de una entrevista de trabajo para una conocida compañía de retail.

# %% [markdown]
# ![tablas1](img/Tablas-1.png)
# ![tablas3](./img/Tablas-3.png)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Crea un DataFrame por cada tabla

# %%
datos = [[1, "1F1", "PULSERAS"],
         [1, "1F2", "ANILLOS"],
         [2, "2F1", "BOLSO DE MANO"],
         [3, "3F1", "NAUTICOS"],
         [3, "3F2", "SANDALIAS"],
         [4, "4F1", "BERMUDAS"]]

columnas = ['ID_DPTO', 'COD_FAMILIA', 'DES_FAMILIA']

familias = pd.DataFrame(datos, columns=columnas)

familias
# Out:
#    ID_DPTO COD_FAMILIA    DES_FAMILIA
# 0        1         1F1       PULSERAS
# 1        1         1F2        ANILLOS
# 2        2         2F1  BOLSO DE MANO
# 3        3         3F1       NAUTICOS
# 4        3         3F2      SANDALIAS
# 5        4         4F1       BERMUDAS

# %%
datos1 = [[1, "JOYERIA"],
         [2, "BOLSOS"],
         [3, "ZAPATERIA"],
         [4, "BAÑO CAB."]]

columnas1 = ['ID_DPTO', 'DES_DPTO']

departamento = pd.DataFrame(datos1, columns=columnas1)

departamento
# Out:
#    ID_DPTO   DES_DPTO
# 0        1    JOYERIA
# 1        2     BOLSOS
# 2        3  ZAPATERIA
# 3        4  BAÑO CAB.

# %%
datos2 = [['A', 1, "1F1", "21/02/2010"],
         ['B', 2, "2F1", "07/02/2014"],
         ['C', 2, "2F1", "15/05/2014"],
         ['D', 2, "2F1", "01/10/2015"],
         ['E', 2, "2F1", "31/10/2010"],
         ['F', 3, "3F1", "20/04/2001"],
         ['G', 3, "3F2", "14/02/2015"],
         ['H', 4, "4F1", "25/03/2009"]]

columnas2 = ['REFERENCIA', 'ID_DPTO', 'COD_FAMILIA', 'FECHA_ALTA']

articulo = pd.DataFrame(datos2, columns=columnas2)

articulo
# Out:
#   REFERENCIA  ID_DPTO COD_FAMILIA  FECHA_ALTA
# 0          A        1         1F1  21/02/2010
# 1          B        2         2F1  07/02/2014
# 2          C        2         2F1  15/05/2014
# 3          D        2         2F1  01/10/2015
# 4          E        2         2F1  31/10/2010
# 5          F        3         3F1  20/04/2001
# 6          G        3         3F2  14/02/2015
# 7          H        4         4F1  25/03/2009

# %%
datos3 = [["CA1", "VENTA", "05/02/2012"],
         ["CA2", "VENTA", "04/02/2012"],
         ["CA3", "POSVENTA", "02/02/2009"],
         ["CA4", "VENTA", "06/02/2010"],
         ["CA5", "POSVENTA", "31/02/2010"],
         ["CA6", "POSVENTA", "07/02/2015"]]

columnas3 = ['ID_CAMPANIA', 'TIPO', 'FECHA_CAMP']

campanias = pd.DataFrame(datos3, columns=columnas3)

campanias
# Out:
#   ID_CAMPANIA      TIPO  FECHA_CAMP
# 0         CA1     VENTA  05/02/2012
# 1         CA2     VENTA  04/02/2012
# 2         CA3  POSVENTA  02/02/2009
# 3         CA4     VENTA  06/02/2010
# 4         CA5  POSVENTA  31/02/2010
# 5         CA6  POSVENTA  07/02/2015

# %%
datos4 = [[1, "CA1"],
         [1, "CA4"],
         [2, "CA2"],
         [3, "CA2"],
         [3, "CA5"],
         [3, "CA6"],
         [4, "CA1"],
         [4, "CA2"],
         [4, "CA3"],
         [4, "CA6"]]

columnas4 = ['ID_DPTO', 'ID_CAMPANIA']

depto_camp = pd.DataFrame(datos4, columns=columnas4)

depto_camp
# Out:
#    ID_DPTO ID_CAMPANIA
# 0        1         CA1
# 1        1         CA4
# 2        2         CA2
# 3        3         CA2
# 4        3         CA5
# 5        3         CA6
# 6        4         CA1
# 7        4         CA2
# 8        4         CA3
# 9        4         CA6

# %%
datos5 = [['01', 'A', 15, "11/02/2012"],
         ['02', 'A', 18, "15/02/2012"],
         ['03', 'A', 14, "02/10/2013"],
         ['04', 'D', 37.95, "06/08/2010"],
         ['05', 'E', 125.95, "31/11/2010"],
         ['06', 'E', 150, "05/02/2011"],
         ['07', 'H', 22.99, "11/04/2010"],
         ['08', 'H', 24, "08/08/2011"]]

columnas5 = ['TALON', 'REFERENCIA', 'PRECIO', 'FECHA_VENTA']

venta = pd.DataFrame(datos5, columns=columnas5)

venta
# Out:
#   TALON REFERENCIA  PRECIO FECHA_VENTA
# 0    01          A   15.00  11/02/2012
# 1    02          A   18.00  15/02/2012
# 2    03          A   14.00  02/10/2013
# 3    04          D   37.95  06/08/2010
# 4    05          E  125.95  31/11/2010
# 5    06          E  150.00  05/02/2011
# 6    07          H   22.99  11/04/2010
# 7    08          H   24.00  08/08/2011

# %%
articulo['FECHA_ALTA'] = pd.to_datetime(articulo['FECHA_ALTA'], format='%d/%m/%Y')
campanias['FECHA_CAMP'] = pd.to_datetime(articulo['FECHA_ALTA'], format='%d/%m/%Y')
venta['FECHA_VENTA'] = pd.to_datetime(venta['FECHA_VENTA'], format='%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     508         try:
# --> 509             values, tz = conversion.datetime_to_datetime64(arg)
#     510             dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/6_/b5rwmy111x5cwz4800tynzq00000gn/T/ipykernel_91645/2843307899.py in <module>
#       1 articulo['FECHA_ALTA'] = pd.to_datetime(articulo['FECHA_ALTA'], format='%d/%m/%Y')
#       2 campanias['FECHA_CAMP'] = pd.to_datetime(articulo['FECHA_ALTA'], format='%d/%m/%Y')
# ----> 3 venta['FECHA_VENTA'] = pd.to_datetime(venta['FECHA_VENTA'], format='%d/%m/%Y')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     885             result = arg.map(cache_array)
#     886         else:
# --> 887             values = convert_listlike(arg._values, format)
#     888             result = arg._constructor(values, index=arg.index, name=arg.name)
#     889     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     392     if format is not None:
#     393         res = _to_datetime_with_format(
# --> 394             arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     395         )
#     396         if res is not None:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     511             return DatetimeIndex._simple_new(dta, name=name)
#     512         except (ValueError, TypeError):
# --> 513             raise err
#     514
#     515
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     499         # fallback
#     500         res = _array_strptime_with_fallback(
# --> 501             arg, name, tz, fmt, exact, errors, infer_datetime_format
#     502         )
#     503         return res
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434
#     435     try:
# --> 436         result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     437         if "%Z" in fmt or "%z" in fmt:
#     438             return _return_parsed_timezone_results(result, timezones, tz, name)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: day is out of range for month

# %% [markdown]
# ## 2. Genera una consulta que obtenga la lista ordenada de todas las referencias sin venta

# %%
con_refe = venta[['REFERENCIA']].copy()
con_refe2 = articulo[['REFERENCIA']].copy()
con_ref_tot = pd.concat([con_refe, con_refe2])
con_ref_tot.sort_values(by=['REFERENCIA'], ascending=True, ignore_index=True)
# Out:
#    REFERENCIA
# 0           A
# 1           A
# 2           A
# 3           A
# 4           B
# 5           C
# 6           D
# 7           D
# 8           E
# 9           E
# 10          E
# 11          F
# 12          G
# 13          H
# 14          H
# 15          H

# %%
df_art_venta = pd.merge(venta, articulo, how='outer')
df_art_no_venta = df_art_venta[df_art_venta['TALON'].isnull()]
df_art_no_venta
# Out:
#    TALON REFERENCIA  PRECIO FECHA_VENTA  ID_DPTO COD_FAMILIA  FECHA_ALTA
# 8    NaN          B     NaN         NaN        2         2F1  07/02/2014
# 9    NaN          C     NaN         NaN        2         2F1  15/05/2014
# 10   NaN          F     NaN         NaN        3         3F1  20/04/2001
# 11   NaN          G     NaN         NaN        3         3F2  14/02/2015

# %% [markdown]
# ## 3. Genera una consulta que obtenga las ventas comprendidas entre 2010 y 2011 (ambos incluidos), que estén asociados a una campaña de tipo VENTA y que sean del departamento de JOYERÍA.

# %%
from datetime import datetime
datetime.strptime('2010-10-11', '%Y-%m-%d')
# Out:
# datetime.datetime(2010, 10, 11, 0, 0)

# %%
vent_art = pd.merge(venta, articulo[['ID_DPTO', 'REFERENCIA']], how='left', on='REFERENCIA')
vent_dpto_camp = pd.merge(vent_art, depto_camp, on='ID_DPTO', how='left')
vent_camp = pd.merge(vent_dpto_camp, campanias, on='ID_CAMPANIA', how='left')
vent_camp = pd.merge(vent_camp, departamento, on='ID_DPTO', how='left')
vent_camp
# Out:
#    TALON REFERENCIA  PRECIO FECHA_VENTA  ID_DPTO ID_CAMPANIA      TIPO  \
# 0     01          A   15.00  11/02/2012        1         CA1     VENTA
# 1     01          A   15.00  11/02/2012        1         CA4     VENTA
# 2     02          A   18.00  15/02/2012        1         CA1     VENTA
# 3     02          A   18.00  15/02/2012        1         CA4     VENTA
# 4     03          A   14.00  02/10/2013        1         CA1     VENTA
# 5     03          A   14.00  02/10/2013        1         CA4     VENTA
# 6     04          D   37.95  06/08/2010        2         CA2     VENTA
# 7     05          E  125.95  31/11/2010        2         CA2     VENTA
# 8     06          E  150.00  05/02/2011        2         CA2     VENTA
# 9     07          H   22.99  11/04/2010        4         CA1     VENTA
# 10    07          H   22.99  11/04/2010        4         CA2     VENTA
# 11    07          H   22.99  11/04/2010        4         CA3  POSVENTA
# 12    07          H   22.99  11/04/2010        4         CA6  POSVENTA
# 13    08          H   24.00  08/08/2011        4         CA1     VENTA
# 14    08          H   24.00  08/08/2011        4         CA2     VENTA
# 15    08          H   24.00  08/08/2011        4         CA3  POSVENTA
# 16    08          H   24.00  08/08/2011        4         CA6  POSVENTA
#
#     FECHA_CAMP   DES_DPTO
# 0   05/02/2012    JOYERIA
# 1   06/02/2010    JOYERIA
# 2   05/02/2012    JOYERIA
# 3   06/02/2010    JOYERIA
# 4   05/02/2012    JOYERIA
# 5   06/02/2010    JOYERIA
# 6   04/02/2012     BOLSOS
# 7   04/02/2012     BOLSOS
# 8   04/02/2012     BOLSOS
# 9   05/02/2012  BAÑO CAB.
# 10  04/02/2012  BAÑO CAB.
# 11  02/02/2009  BAÑO CAB.
# 12  07/02/2015  BAÑO CAB.
# 13  05/02/2012  BAÑO CAB.
# 14  04/02/2012  BAÑO CAB.
# 15  02/02/2009  BAÑO CAB.
# 16  07/02/2015  BAÑO CAB.

# %% [markdown]
# ## 4. Genere una consulta que cree un campo “co_ranking” que clasifique en orden ascendente las campañas según el total de venta, siendo 1 la campaña que más ha vendido y N la que menos. (N = Total de campañas)

# %%
vent_camp['FECHA_VENTA'].apply(lambda x: x.year)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/6_/b5rwmy111x5cwz4800tynzq00000gn/T/ipykernel_91645/23600042.py in <module>
# ----> 1 vent_camp['FECHA_VENTA'].apply(lambda x: x.year)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/6_/b5rwmy111x5cwz4800tynzq00000gn/T/ipykernel_91645/23600042.py in <lambda>(x)
# ----> 1 vent_camp['FECHA_VENTA'].apply(lambda x: x.year)
#
# AttributeError: 'str' object has no attribute 'year'

# %% [markdown]
# ## 5. Clasifique todas las ventas en Mayor, Igual o Menor precio respecto a la media de los precios de todas las ventas realizadas.

# %% [markdown]
# **Resultado**:
#
#
# ![tablares](img/Tablas-4.png)

# %%
avg_precio = venta['PRECIO'].mean()
def clasif(fila, media):
    if fila['PRECIO'] < media:
        return 'Menor'
    elif fila['PRECIO'] == media:
        return 'Igual'
    else:
        return 'Mayor'

venta['CLASIFICACION'] = venta.apply(lambda fila: clasif(fila, avg_precio), axis=1)
venta
# Out:
#   TALON REFERENCIA  PRECIO FECHA_VENTA CLASIFICACION
# 0    01          A   15.00  11/02/2012         Menor
# 1    02          A   18.00  15/02/2012         Menor
# 2    03          A   14.00  02/10/2013         Menor
# 3    04          D   37.95  06/08/2010         Menor
# 4    05          E  125.95  31/11/2010         Mayor
# 5    06          E  150.00  05/02/2011         Mayor
# 6    07          H   22.99  11/04/2010         Menor
# 7    08          H   24.00  08/08/2011         Menor

# %% [markdown]
# # 7. Genere una consulta que para cada campaña de tipo “venta” obtenga el talón medio, precio medio, nº de referencias compradas y nº de talones con venta superior al talón medio.

# %% [markdown]
# ## 8. Genere una o varias consultas que devulevan las combinaciones de familias y campañas cuya venta haya sido superior a 100€.

# %% [markdown]
# ## 9. Genere una o varias consultas que permitan catalogar los artículos vendidos y que no son de la Campaña CA1, según si se tratan de artículos de Ropa o Accesorios. En base a los departamentos y familias. NOTA: Se valorará la elaboración de la consulta y no la veracidad del propio catálogo)

# %% [markdown]
# ## 10. Genere una o varias consultas que devuelvan la variación del total de venta entre años. Tomando como variación la siguiente fórmula $$\dfrac{Year_{n} – Year_{n-1}}{Year_{n-1}}$$ (Se valorará el control de valores 0 en la división o de indeterminaciones)

# %% [markdown]
# ![tablas5](img/Tablas-5.png)
